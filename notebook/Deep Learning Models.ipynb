# %%
# Import required packages

import glob
import random
import datetime
import os, fnmatch
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.externals import joblib

# from tensorflow.python.keras.models import Sequential
# from tensorflow.python.keras.layers import Dense
# from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor

# %matplotlib inline

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
# Load the dataset
df = pd.read_csv("../dataset/users_data/153592.csv")

# Print top 5 reeocrds of dataset
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  xSubscriptionId_fk  xCycleCode  xFamilyNum  \
# 0     1576788       1576788              153592          10           1
# 1     1579165       1579165              153592          10           1
# 2     1579166       1579166              153592          10           1
# 3     1579167       1579167              153592          10           1
# 4     1579168       1579168              153592          10           1
#
#    xFaze  xAmper  xCounterBuldingNo  xRegionName_Roustaei  xRegionName_Shahri  \
# 0      1       5           62694457                     0                   1
# 1      1       5           62694457                     0                   1
# 2      1       5           62694457                     0                   1
# 3      1       5           62694457                     0                   1
# 4      1       5           62694457                     0                   1
#
#    xUsageGroupName_Keshavarzi  xUsageGroupName_Khanegi  \
# 0                           0                        1
# 1                           0                        1
# 2                           0                        1
# 3                           0                        1
# 4                           0                        1
#
#    xUsageGroupName_Omoomi  xUsageGroupName_Sanati  xUsageGroupName_Sayer  \
# 0                       0                       0                      0
# 1                       0                       0                      0
# 2                       0                       0                      0
# 3                       0                       0                      0
# 4                       0                       0                      0
#
#    xBakhshCode_1  xBakhshCode_2  xBakhshCode_4  xTimeControlCode_1  \
# 0              0              0              1                   0
# 1              0              0              1                   0
# 2              0              0              1                   0
# 3              0              0              1                   0
# 4              0              0              1                   0
#
#    xTimeControlCode_2  xTimeControlCode_3  xTariffOldCode_1010  \
# 0                   0                   1                    1
# 1                   0                   1                    1
# 2                   0                   1                    1
# 3                   0                   1                    1
# 4                   0                   1                    1
#
#    xTariffOldCode_1011  xTariffOldCode_1110  xTariffOldCode_1111  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_1990  xTariffOldCode_2110  xTariffOldCode_2210  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_2310  xTariffOldCode_2410  xTariffOldCode_2510  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_2610  xTariffOldCode_2710  xTariffOldCode_2990  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_2992  xTariffOldCode_3110  xTariffOldCode_3210  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_3310  xTariffOldCode_3410  xTariffOldCode_3520  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_3540  xTariffOldCode_3740  xTariffOldCode_3991  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_4410  xTariffOldCode_4610  xTariffOldCode_4990  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    xTariffOldCode_5110  xTariffOldCode_5990  days_difference  month  \
# 0                    0                    0               65      2
# 1                    0                    0               57      4
# 2                    0                    0               60      6
# 3                    0                    0               56      8
# 4                    0                    0               65     10
#
#    mediumDailyUsage  highDailyUsage  lowDailyUsage  xMeduimKw  xHighKw  xLowKw
# 0          0.553846        1.169231       1.415385         36       76      92
# 1          0.140351        1.263158       1.122807          8       72      64
# 2          1.450000        1.483333       1.400000         87       89      84
# 3          1.464286        1.232143       1.214286         82       69      68
# 4          1.553846        1.215385       1.353846        101       79      88
